# %%
# -*- coding: utf-8 -*-
"""
import_qualtrics_surveys- Uses Qualtrics API to automate the import and activation of the meaning map patch rating surveys.

@author: Taylor R. Hayes
"""

#%% 010: Import modules and define relative folder path

# Set your project ID and your API token here
# MSB : mUYDofbqRqWRh57qOcHr1vBjwTBWpKwT6PATbaHI   
apiToken = "mUYDofbqRqWRh57qOcHr1vBjwTBWpKwT6PATbaHI" # This can be found in your Qualtrics account settings->Qualtrics IDs

import os
import re
import requests
import json
from datetime import datetime  
from datetime import timedelta 
from natsort import natsorted, ns
from time import sleep

relpath = os.path.dirname(os.path.realpath('__file__'))

# %%
#%% 020: Define various API functions

###################
# Import Survey API 
###################
def import_survey(survey,survey_file,name,apiToken):    
    
    # Setting user Parameters
    dataCenter = "co1"	# UC Davis ID
    
    # Defining inputs
    baseUrl = "https://ucdavis.co1.qualtrics.com/API/v3/surveys".format(dataCenter)
    headers = {
        "x-api-token": apiToken,
        }
    
    files = {
        'file': (survey, open(survey_file, 'rb'), 'application/vnd.qualtrics.survey.txt')
        }
    
    data = { "name": name }
    
    # Make response and print output
    response = requests.post(baseUrl, files=files, data=data, headers=headers)
    print(response.text)
    return response


###############
# Update Survey
###############

def update_survey(surveyId,name,apiToken):
    
    # Setting user Parameters
    dataCenter = "co1"	
    
    baseUrl = "https://{0}.qualtrics.com/API/v3/surveys/{1}".format(dataCenter, surveyId)
    headers = {
        "content-type": "application/json",
        "x-api-token": apiToken,
        }
    
    data = { 
        "name": name, 
        "isActive": True, 
        "expiration": { 
            "startDate": datetime.now().strftime("%Y-%m-%dT%H:%M:%SZ"), 
            "endDate": (datetime.now()+timedelta(days=90)).strftime("%Y-%m-%dT%H:%M:%SZ")
        } 
      }
    
    response = requests.put(baseUrl, json=data, headers=headers)
    print(response.text)


################
# Get Survey API
################

def get_survey(surveyId,apiToken):

    # Setting user Parameters
    dataCenter = "co1"	
    
    baseUrl = "https://{0}.qualtrics.com/API/v3/surveys/{1}".format(dataCenter, surveyId)
    headers = {
        "x-api-token": apiToken,
        }
    
    response = requests.get(baseUrl, headers=headers)
    #print(response.text)
    return response

###################
# Delete Survey API
###################

def delete_survey(surveyId,apiToken):
    
    # Setting user Parameters
    dataCenter = "co1"	
    
    baseUrl = "https://{0}.qualtrics.com/API/v3/surveys/{1}".format(dataCenter, surveyId)
    headers = {
        "x-api-token": apiToken,
        }
    
    response = requests.delete(baseUrl, headers=headers)
    print(response.text)

# %%
task_path = relpath

os.path.isdir(task_path)
# Out:
# True

# %%
coarse_path
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-52300eae01c4> in <module>
# ----> 1 coarse_path
#
# NameError: name 'coarse_path' is not defined

# %%
all_ids = []

for task in os.listdir(task_path):
    if os.path.isdir(os.path.join(task_path,task)) and task in ['meaning']:
        relpath = os.path.join(task_path,task)

        project_ID = 'EDesc01_'+task.split('_')[0] # This will be the name stem for each survey

        #%% 030: Import and generate all fine patch jobs in Qualtrics

        #-- Get fine survey files
        fine_path = os.path.join(relpath,'fine')
        fine_files = os.listdir(fine_path)
        fine_files = natsorted(fine_files, alg=ns.IGNORECASE)

        #-- For each file
        for x in fine_files:

            #-- Create survey
            survey_file = os.path.join(fine_path, x)
            survey_number = re.findall("\d+", x)
            name = project_ID + '_fine' +  survey_number[0].rjust(3,"0") # Qualtrics name sort

            #-- Call API to import survey
            response = import_survey(x, survey_file, name, apiToken)

            #-- Extract survey id from response.text
            response_list = re.findall('"([^"]*)"', response.text)
            surveyId = response_list[2] 

            all_ids.append(surveyId)
            
            #-- Activate survey
            update_survey(surveyId,name,apiToken)
            
            sleep(1)


        #%% 040: Import and generate all coarse patch jobs in Qualtrics

        #-- Get fine survey files
        coarse_path = os.path.join(relpath,'coarse')
        coarse_files = os.listdir(coarse_path)
        coarse_files = natsorted(coarse_files, alg=ns.IGNORECASE)

        #-- For each file
        for x in coarse_files:

            #-- Create survey
            survey_file = os.path.join(coarse_path, x)
            survey_number = re.findall("\d+", x)
            name = project_ID + '_coarse' +  survey_number[0].rjust(3,"0") # Qualtrics name sort

            #-- Call API to import survey
            response = import_survey(x, survey_file, name, apiToken)

            #-- Extract survey id from response.text
            response_list = re.findall('"([^"]*)"', response.text)
            surveyId = response_list[2] 
            
            all_ids.append(surveyId)

            #-- Activate survey
            update_survey(surveyId,name,apiToken)
            
            sleep(1)

        # END OF IMPORT_QUALTRICS_SURVEYS

with open(os.path.join(task_path,task,'survey_ids.txt'),'w') as outfile:
    for id_str in all_ids:
        outfile.write(id_str+"\n")
outfile.close()
# Out:
# {"result":{"id":"SV_9MOTuUFUHnGgU9E"},"meta":{"httpStatus":"200 - OK","requestId":"df9ee54c-9624-4cc3-ad7e-f3bdcaca459b"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"d5bdfbf7-4b8c-4b31-a844-43a7d786c1f5"}}
# {"result":{"id":"SV_baa2HgZsF14NrVA"},"meta":{"httpStatus":"200 - OK","requestId":"cd4a85b9-d92b-43dc-b80b-d1bd0d061fbd"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"3dc50b34-33e3-4c5c-be1e-14d3d9f72e22"}}
# {"result":{"id":"SV_73ZqSFutaPg6eLI"},"meta":{"httpStatus":"200 - OK","requestId":"4fbff753-7adb-4f87-a19e-a747ab7bc076"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"79a0fbb8-4c3c-48e8-aa4e-0b2fadaff27e"}}
# {"meta":{"httpStatus":"500 - Internal Server Error","error":{"errorMessage":"Internal server error. Please contact Qualtrics support.","errorCode":"CS_5.2","instanceId":"8f0e2754-e3ee-409c-8294-d71647b7684c"},"requestId":"9856b300-51ab-4496-8f32-607cef1c6bf9"}}
# {"meta":{"httpStatus":"400 - Bad Request","error":{"errorMessage":"Invalid surveyId.","errorCode":"USI_1.0"},"requestId":"4c323fba-3cc0-441d-9ead-d6d8f62b643d"}}
# {"result":{"id":"SV_0UFgyDk4KE7iz1c"},"meta":{"httpStatus":"200 - OK","requestId":"d3bbd715-22e7-4ab7-ae23-fa3d956d13ce"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"f2dace7c-a68f-46ac-9513-4f42613577de"}}
# {"result":{"id":"SV_0HSmdqkAXQei9qS"},"meta":{"httpStatus":"200 - OK","requestId":"3d51c13d-d1ec-4106-8261-943c8e0290ec"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"5254e137-6676-4a7c-bd06-d28550808990"}}
# {"result":{"id":"SV_8D2O2uh0Fi46bFc"},"meta":{"httpStatus":"200 - OK","requestId":"319bde60-570d-40ce-884a-6a12460781c5"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"2c2a60ea-fe15-4d6d-bb52-f04d5fe37bda"}}
# {"meta":{"httpStatus":"500 - Internal Server Error","error":{"errorMessage":"Internal server error. Please contact Qualtrics support.","errorCode":"CS_5.2","instanceId":"aca9c6d2-0e8a-4400-ae20-1718f570a1ee"},"requestId":"f5e50416-53c1-4280-897e-ecbd4d3cdbb4"}}
# {"meta":{"httpStatus":"400 - Bad Request","error":{"errorMessage":"Invalid surveyId.","errorCode":"USI_1.0"},"requestId":"23f90c17-c80e-47b2-b984-110e5ba8ce6c"}}
# {"result":{"id":"SV_8InwnTVKsnrsloy"},"meta":{"httpStatus":"200 - OK","requestId":"92e32050-a488-4559-b289-59b5e4dbb456"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"c6f08de0-0bf1-4746-815d-2b01122086a1"}}
# {"meta":{"httpStatus":"500 - Internal Server Error","error":{"errorMessage":"Internal server error. Please contact Qualtrics support.","errorCode":"CS_5.2","instanceId":"4d119759-af19-4bfe-af51-546843671f69"},"requestId":"14c1a606-6797-4484-9e77-06bb636fc173"}}
# {"meta":{"httpStatus":"400 - Bad Request","error":{"errorMessage":"Invalid surveyId.","errorCode":"USI_1.0"},"requestId":"d2d1e077-f074-4df0-a3a5-03b201703299"}}
# {"meta":{"httpStatus":"500 - Internal Server Error","error":{"errorMessage":"Internal server error. Please contact Qualtrics support.","errorCode":"CS_5.2","instanceId":"23a26841-46b7-4128-979f-994cd8f1ad4c"},"requestId":"7b2b7c3e-09bc-42a0-a195-5dd078f050a6"}}
# {"meta":{"httpStatus":"400 - Bad Request","error":{"errorMessage":"Invalid surveyId.","errorCode":"USI_1.0"},"requestId":"d90de353-2ffd-4354-8747-2576b32e968a"}}
# {"meta":{"httpStatus":"500 - Internal Server Error","error":{"errorMessage":"Internal server error. Please contact Qualtrics support.","errorCode":"CS_5.2","instanceId":"79adc389-1434-4224-996d-3ef0481bbc8b"},"requestId":"b9db383d-28c8-47a3-9412-091c16633ead"}}
# {"meta":{"httpStatus":"400 - Bad Request","error":{"errorMessage":"Invalid surveyId.","errorCode":"USI_1.0"},"requestId":"e722738b-898c-4e15-a446-5eee9e8745a1"}}
# {"meta":{"httpStatus":"500 - Internal Server Error","error":{"errorMessage":"Internal server error. Please contact Qualtrics support.","errorCode":"CS_5.2","instanceId":"47716df3-8624-4005-b6d9-471f7b440ff6"},"requestId":"e05f44d5-0e7a-4389-92ed-1b81f3fe2378"}}
# {"meta":{"httpStatus":"400 - Bad Request","error":{"errorMessage":"Invalid surveyId.","errorCode":"USI_1.0"},"requestId":"fce9da2c-7577-4bac-8c25-4fd990558fc5"}}
# {"result":{"id":"SV_begdAzO8T9TmaI6"},"meta":{"httpStatus":"200 - OK","requestId":"d66c7690-7bda-41c1-820a-906d783e8881"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"92fe728f-85e0-40ea-8717-992777d43175"}}
# {"result":{"id":"SV_3CwanS1cEn1VKNU"},"meta":{"httpStatus":"200 - OK","requestId":"90d2ad7c-cfbd-403b-8cf5-2263e0c8ba11"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"7a68584c-3390-4cf2-bafb-64104c13802b"}}
# {"result":{"id":"SV_01BWILD2Jg1lhu6"},"meta":{"httpStatus":"200 - OK","requestId":"9a15652f-438c-4453-b128-d33cdd03ea68"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"bd841fa8-3914-47e7-86a1-75328efca9f9"}}
# {"result":{"id":"SV_3pA8xvRvBnXuS34"},"meta":{"httpStatus":"200 - OK","requestId":"9e39f5fa-36e8-4510-88bb-39bf8ed31d20"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"060d67d2-7727-4000-b1a0-ae1fb4a07667"}}
# {"meta":{"httpStatus":"500 - Internal Server Error","error":{"errorMessage":"Internal server error. Please contact Qualtrics support.","errorCode":"CS_5.2","instanceId":"f92f3443-a184-4b53-acfd-4db13f7f7b26"},"requestId":"f9bc049f-4eca-4cd0-82f1-96750776530d"}}
# {"meta":{"httpStatus":"400 - Bad Request","error":{"errorMessage":"Invalid surveyId.","errorCode":"USI_1.0"},"requestId":"52798875-db6f-4e2d-a236-1cd6f1f82dad"}}
# {"result":{"id":"SV_b1wBWbbpaywmofA"},"meta":{"httpStatus":"200 - OK","requestId":"82b5aa73-8e25-457e-a081-36e21cebd4a8"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"91ee5b00-f274-407b-b322-266d9383da67"}}
# {"meta":{"httpStatus":"500 - Internal Server Error","error":{"errorMessage":"Internal server error. Please contact Qualtrics support.","errorCode":"CS_5.2","instanceId":"3255df0d-c193-4c01-ade8-c783bedcb5b2"},"requestId":"9d5d7922-d5bb-4ffe-9608-5ad9ba8c9aee"}}
# {"meta":{"httpStatus":"400 - Bad Request","error":{"errorMessage":"Invalid surveyId.","errorCode":"USI_1.0"},"requestId":"114bff65-e202-4531-a786-87b1c678e166"}}
# {"result":{"id":"SV_803PQB9KoX1pTuK"},"meta":{"httpStatus":"200 - OK","requestId":"10acf196-4ee1-4c3e-bc8d-b3cb5a1b6f14"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"95217ab2-47f2-4c2f-a8f5-69cf57fa3e37"}}
# {"result":{"id":"SV_bf65RMqXNjqZXdc"},"meta":{"httpStatus":"200 - OK","requestId":"d2329827-ff92-4da4-96d9-88b3b7f2445a"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"5ec593a6-0630-4527-9cea-c157150b6e52"}}
# {"result":{"id":"SV_ePvhcvtO8FqTAVg"},"meta":{"httpStatus":"200 - OK","requestId":"97978a20-f505-4b8e-a8d4-c7ec7f36598b"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"99dcd36c-5566-4cc1-aa04-226b44e96434"}}
# {"meta":{"httpStatus":"500 - Internal Server Error","error":{"errorMessage":"Internal server error. Please contact Qualtrics support.","errorCode":"CS_5.2","instanceId":"696eb0c0-aeae-4f2d-8864-42c55eb84422"},"requestId":"9af7f782-ee1a-42ed-a029-278438e0101e"}}
# {"meta":{"httpStatus":"400 - Bad Request","error":{"errorMessage":"Invalid surveyId.","errorCode":"USI_1.0"},"requestId":"cd494507-cb28-4a3e-a9e9-6962a22956b2"}}
# {"result":{"id":"SV_3yFKCbmK9bHFcvY"},"meta":{"httpStatus":"200 - OK","requestId":"f4f29348-af1e-495c-a1d5-8324ae5c12d8"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"bbe5c23e-bf4b-48db-b40e-4b3472c688c0"}}
# {"result":{"id":"SV_6hBZHMrKgo8KyUe"},"meta":{"httpStatus":"200 - OK","requestId":"d0d6e167-411b-47c4-af78-0c14f90893dc"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"d6477e71-bd84-4a08-8cd1-625c520fe901"}}
# {"result":{"id":"SV_38as3vXQ2cdNVVY"},"meta":{"httpStatus":"200 - OK","requestId":"1c87481f-aead-4cbb-bb29-23b5caf1eeb1"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"27f1f32f-d6f5-48d7-ad05-bbcaf74f54b0"}}
# {"meta":{"httpStatus":"500 - Internal Server Error","error":{"errorMessage":"Internal server error. Please contact Qualtrics support.","errorCode":"CS_5.2","instanceId":"fda07b8a-040f-4803-8479-4c602a06ea4b"},"requestId":"055d3ebb-4e73-470e-9dc0-f3559ab540cd"}}
# {"meta":{"httpStatus":"400 - Bad Request","error":{"errorMessage":"Invalid surveyId.","errorCode":"USI_1.0"},"requestId":"05f0791e-d20c-4211-8005-2127e6a99f6c"}}
# {"result":{"id":"SV_2nT6aQzO4t6Yjcy"},"meta":{"httpStatus":"200 - OK","requestId":"c0269008-ca70-44f5-81e9-39bc8d0df4c6"}}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-1b5c1bc448d1> in <module>
#      32
#      33             #-- Activate survey
# ---> 34             update_survey(surveyId,name,apiToken)
#      35
#      36             sleep(1)
#
# <ipython-input-16-88fc5e0cbfae> in update_survey(surveyId, name, apiToken)
#      51       }
#      52
# ---> 53     response = requests.put(baseUrl, json=data, headers=headers)
#      54     print(response.text)
#      55
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in put(url, data, **kwargs)
#     132     """
#     133
# --> 134     return request('put', url, data=data, **kwargs)
#     135
#     136
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in getresponse(self)
#    1330         try:
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#    1334                 self.close()
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in begin(self)
#     301         # read until we get a non-100 response
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#     305                 break
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in _read_status(self)
#     262
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#     266             raise LineTooLong("status line")
#
# ~/opt/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
with open(os.path.join(task_path,task,'survey_ids.txt'),'w') as outfile:
    for id_str in all_ids:
        outfile.write(id_str+"\n")
outfile.close()

# %%
task = 'grasp' # Set to the task surveys to populate

existing_surveys = open(os.path.join(task_path,task,'survey_ids.txt'),'r').readlines()
existing_surveys = [d.replace('\n','') for d in existing_surveys]

# %%
# Retrieve surveys from Qualtrics to get actual QIDs

get_survey_path = os.path.join(task_path,task,'from_qualtrics')

if not os.path.isdir(get_survey_path):
    os.mkdir(get_survey_path)

for f in existing_surveys:
    tmp = get_survey(f,apiToken)
    text = tmp.text
    name = text.split('"name":"')[1].split('"')[0]+'.txt'
    f = open(os.path.join(get_survey_path,name),'w',encoding='UTF-8')
    f.write(text)
    f.close()

# %%
os.path.join(get_survey_path,name)
# Out:
# 'C:\\Users\\gwenz\\Box\\FerreiraLabShare\\TDrive backup\\Gwen\\MeaningMap_Verbal\\Running\\Stimuli\\SDesc01\\mapping\\surveys\\grasp\\from_qualtrics\\SDesc01_grasp_fine001.txt'

# %%
# Delete surveys
task = 'interact' # Set to the task surveys to be deleted
to_delete = existing_surveys

for survey in to_delete:
    delete_survey(survey,apiToken)
# Out:
# {"meta":{"httpStatus":"200 - OK","requestId":"29be6894-43b1-4a13-85e1-5959d1306f33"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"f9111bb0-435b-43bb-b31e-06397096035b"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"e7a765d5-ab01-4e12-8df5-e7b0f59718cb"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"d11d9f20-7f56-4969-a7f2-e5e222395646"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"cf13de1f-00bb-4231-b2f6-5c7f11dfef42"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"adbd8f75-5725-428f-aa8e-b67fd54ed6de"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"30dc9cfe-4f67-431b-a75e-fade452e18f0"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"da83cdc5-ce02-4c02-83a1-88ad290c2dc6"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"69570b63-ee85-44f4-a300-2ea5d0fc1cb1"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"1f6eed02-53ac-48ca-ba35-3fd3503593e1"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"d0803ac0-8214-4f99-b827-ca1c120632bf"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"5027b9b6-6ff9-466e-a109-4839208f5971"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"37209b1b-f119-4135-8d7f-81a1f7753a51"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"7bf95541-1ffd-49fe-b335-0c8e1428f0a3"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"a7fa3cfe-8b00-4baa-b43e-09aa464f52cc"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"eeb36cda-92f3-4da2-9270-7ac7cf372fbf"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"ebd16a7f-613e-4938-be67-e6150180871e"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"212cfa65-c458-43b1-b481-b6be75eec2a9"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"8a9d70db-82bd-4afd-8a83-4b0bcac9352e"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"22425a21-7b80-4ffa-b8eb-e415443a8a87"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"cf4df8e5-6322-439f-ae52-2324070b2887"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"cff75236-5339-4b05-8a02-fb3125a066f4"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"ccf27436-3f2d-4ee9-8743-3c08f2491e28"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"61d73c65-71d5-4d6d-8424-323718a5aad8"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"27644747-04b3-45c1-bfbe-da8c19e093ad"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"cd951c2f-c4b1-4139-b743-3067c4aee9f3"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"a0133e9b-e757-43cd-aa4b-787f6e3cc61b"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"5621d825-6d4c-4ca0-ab13-268a5e40aca7"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"aef04dc7-1c04-4f0a-84db-dde8376c4614"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"c0debc93-4822-4ab1-a0ad-48b70a4b35e5"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"3fda97b4-ef96-4cd0-a3c6-0e5442f8559b"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"bc1b9c8e-fb26-4e83-9918-5558a792fbd2"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"e08c3d68-d286-48b7-924c-e4b700cf55cf"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"1cc7f1e3-e628-4f28-b06c-61b90082cedd"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"1ee711f4-c73a-4346-b8a6-0b3f89dc9384"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"0f257764-a967-4254-a4c4-0f7e6baeca39"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"23de6c34-afef-4cf1-97e6-c793319e28a1"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"30bbe450-78c5-4925-80a5-f35f2d528331"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"60014719-e08a-4a33-99bf-bb7008f4a4a4"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"2a3b2cd1-2784-4ac4-a36d-f84b8e133429"}}
# {"meta":{"httpStatus":"200 - OK","requestId":"f1e22273-511a-42aa-923f-c2f161a15ca7"}}
